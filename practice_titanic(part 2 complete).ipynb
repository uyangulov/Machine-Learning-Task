# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
data = pd.read_csv('C:\\Users\\kirill\\Desktop\\project_case\\titanic_train.csv',
                  index_col='PassengerId')

# %%
data.head(20)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 19                  0       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# ...

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200
#
#            is_old
# count  405.000000
# mean     0.051852
# std      0.222002
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
data = data.drop('Cabin', axis=1).dropna()

# %%
data["is_old"] = data.Age.map(lambda x: 1 if x >60 else 0 if x < 30 else None) #создаем две возрастные группы

# %%
# В задании сказано построить зависимости между признаками Embarked и Sex но они  НЕ ЯВЛЯЮТСЯ ЧИСЛЕННЫМИ, поэтому
# закодируем их в следующем формате:
#     Embarked:
#         Q -> 0
#         S -> 1
#         C -> 2
#     Sex:
#         1 -> male
#         0 -> female
# разместим эти значения в новых столбцах

data['Embarked_num'] = data['Embarked'].map({'Q': 0, 'S': 1, 'C':2})
data['Sex_num'] = data['Sex'].map({"female":0, "male": 1})

# %%
sns.pairplot(data[['Survived', 'Age', 'Fare', 'SibSp', 'Parch', 'Embarked_num', 'Sex_num']]);

# %%
pd.plotting.scatter_matrix(data,figsize=(10, 10), diagonal='kde')
 plt.show()

# %%
sns.boxplot(x='Pclass', y='Fare', data=data);

# %%
train_df['Fare_no_out'] = train_df['Fare']
fare_pclass1 = data[data['Pclass'] == 1]['Fare']
fare_pclass2 = data[data['Pclass'] == 2]['Fare']
fare_pclass3 = data[data['Pclass'] == 3]['Fare']
fare_pclass1_no_out = # Ваш код здесь
fare_pclass2_no_out = # Ваш код здесь
fare_pclass3_no_out = # Ваш код здесь
data['Fare_no_out'] = fare_pclass1_no_out.append(fare_pclass2_no_out)\
                                             .append(fare_pclass3_no_out)
# Out:
#   File "<ipython-input-160-7b5f0cd384fd>", line 5
#     fare_pclass1_no_out = # Ваш код здесь
#                                          ^
# SyntaxError: invalid syntax

# %%
plt.title('Survival rate among 0-30 and 60+ year-olds')
plt.xlabel('Survived')
plt.ylabel('Survival rate')

bins = np.arange(-2,2,0.1)

data_young = data[(data.is_old == 0)].dropna()["Survived"] #делаем выборку из датасета, где Age<30 и >60 соответственно
data_old = data[(data.is_old == 1)].dropna()["Survived"]


hist_young, edges = np.histogram(data_young, bins)
hist_old, edges = np.histogram(a1, bins)

#делим количество выживших на общее количество обьектов в выборке
#(у нас две выборки. Одна содержит только пожилых, другая только молодых)

surv_rate_young = hist_young/float(hist_young.sum())
surv_rate_old = hist_old/float(hist_old.sum())


plt.bar(bins[:-1],freq,width=0.1, align="edge", color ="blue", alpha = 1,  label='Age<30' )
plt.bar(bins1[:-1],freq1 ,width=0.15, align="edge", alpha = 0.35, color = "black",  label='Age>60')

plt.legend(loc='best')
plt.show()

hist, hist1 = plt.subplots(1,0)

#Из гистограммы можно сделать вывод, что молодые выживали чаще, чем пожилые
#Столбцы на гистограмме расположени в соответствии со значениями Surived = 1(выжил) и Surived = 0(не выжил)

# %%
sns.boxplot(x='Survived', y='Age', data=data.dropna());
